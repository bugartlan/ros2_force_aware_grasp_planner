# %%
# %load_ext autoreload
# %autoreload 2

import meshio
import torch
from graph_builder import GraphVisualizer
from utils import msh_to_trimesh

# %% [markdown]
# ## Load Graphs and Visualize

# %%
data = torch.load("../data/Factory50/SpurGear1_50.pt", weights_only=False)
# data = torch.load("data/Primitives100/HexagonBore1_100.pt", weights_only=False)

idx = 8

graphs = data["graphs"]
mesh = data["mesh"]

print(mesh)

visualizer = GraphVisualizer(msh_to_trimesh(meshio.read(f"../{mesh}")))
g = graphs[idx]

visualizer.stress(g, debug=True)
visualizer.bottom(g)
